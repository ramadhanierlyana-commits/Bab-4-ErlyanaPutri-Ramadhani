# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanierlyana-commits/Bab-4-ErlyanaPutri-Ramadhani/blob/main/Post_Test_Bab_4_Erlyana_Putri_Ramadhani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo, Erlyn")
# Out:
# Haloo, Erlyn
