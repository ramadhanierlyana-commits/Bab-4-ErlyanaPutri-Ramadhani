# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanierlyana-commits/Bab-4-ErlyanaPutri-Ramadhani/blob/main/Sistem_Panen_Erlyana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git init
git status
git add panen.py
git commit -m "Menambahkan program penghitung total hasil panen"
git log --oneline
# Out:
#   File "/tmp/ipykernel_2120/607550094.py", line 1
#     git init
#         ^
# SyntaxError: invalid syntax
