# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanierlyana-commits/Bab-4-ErlyanaPutri-Ramadhani/blob/main/Nomor_3_Erlyana_Putri_Ramadhani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Sistem_Panen_Erlyana.ipynb
# Out:
# Cloning into 'Sistem_Panen_Erlyana.ipynb'...
# remote: Not Found
# fatal: repository 'https://github.com/Sistem_Panen_Erlyana.ipynb/' not found

# %%
# %cd /content/sistem-panen-erlyana
# Out:
# [Errno 2] No such file or directory: '/content/sistem-panen-erlyana'
# /content

# %%
# !ls

# %%
# %%writefile panen.py
hasil_panen = [10, 15, 20, 12]

total = sum(hasil_panen)

print("Hasil panen:", hasil_panen)
print("Total hasil panen:", total, "kg")
# Out:
# Writing panen.py
